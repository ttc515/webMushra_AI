# %% [markdown]
# # Designing MUSRHA Tests using webMUSHRA and PyMUSHRA

# %% [markdown]
# Schoeffler, M. et al., (2018). webMUSHRA — A Comprehensive Framework for Web-based Listening Tests. Journal of Open Research Software. 6(1), p.8.

# %% [markdown]
# ## Installing webMUSHRA anb PyMUSHRA

# %%
import os
import shutil
import stat

# !mkdir db
# Function to force delete read-only files
def remove_readonly(func, path, _):
    os.chmod(path, stat.S_IWRITE)
    func(path)

# Directories to manage
repos = {
    "webmushra": "https://github.com/ttc515/webMushra_AI.git",
    "pymushra": "https://github.com/ttc515/pyMushra_mod.git"
}

for folder, repo_url in repos.items():
    if os.path.exists(folder):
        print(f"Removing existing folder: {folder}")
        shutil.rmtree(folder, onerror=remove_readonly)
    # Clone the repository
    # !git clone {repo_url} {folder}

# !pip install -e pymushra
# Out:
# Removing existing folder: webmushra
# A subdirectory or file db already exists.
# Removing existing folder: pymushra
# Cloning into 'webmushra'...
# Updating files:   7% (30/395)
# Updating files:   8% (32/395)
# Updating files:   9% (36/395)
# Updating files:  10% (40/395)
# Updating files:  11% (44/395)
# Updating files:  12% (48/395)
# Updating files:  13% (52/395)
# Updating files:  14% (56/395)
# Updating files:  15% (60/395)
# Updating files:  16% (64/395)
# Updating files:  17% (68/395)
# Updating files:  18% (72/395)
# Updating files:  19% (76/395)
# Updating files:  20% (79/395)
# Updating files:  21% (83/395)
# Updating files:  22% (87/395)
# Updating files:  23% (91/395)
# Updating files:  24% (95/395)
# Updating files:  25% (99/395)
# Updating files:  26% (103/395)
# Updating files:  27% (107/395)
# Updating files:  28% (111/395)
# Updating files:  28% (112/395)
# Updating files:  29% (115/395)
# Updating files:  30% (119/395)
# Updating files:  31% (123/395)
# Updating files:  32% (127/395)
# Updating files:  33% (131/395)
# Updating files:  34% (135/395)
# Updating files:  35% (139/395)
# Updating files:  36% (143/395)
# Updating files:  37% (147/395)
# Updating files:  38% (151/395)
# Updating files:  39% (155/395)
# Updating files:  40% (158/395)
# Updating files:  41% (162/395)
# Updating files:  42% (166/395)
# Updating files:  43% (170/395)
# Updating files:  44% (174/395)
# Updating files:  45% (178/395)
# Updating files:  46% (182/395)
# Updating files:  47% (186/395)
# Updating files:  48% (190/395)
# Updating files:  49% (194/395)
# Updating files:  50% (198/395)
# Updating files:  51% (202/395)
# Updating files:  52% (206/395)
# Updating files:  53% (210/395)
# Updating files:  54% (214/395)
# Updating files:  55% (218/395)
# Updating files:  56% (222/395)
# Updating files:  57% (226/395)
# Updating files:  58% (230/395)
# Updating files:  59% (234/395)
# Updating files:  60% (237/395)
# Updating files:  61% (241/395)
# Updating files:  62% (245/395)
# Updating files:  63% (249/395)
# Updating files:  64% (253/395)
# Updating files:  65% (257/395)
# Updating files:  66% (261/395)
# Updating files:  67% (265/395)
# Updating files:  68% (269/395)
# Updating files:  69% (273/395)
# Updating files:  70% (277/395)
# Updating files:  71% (281/395)
# Updating files:  72% (285/395)
# Updating files:  73% (289/395)
# Updating files:  74% (293/395)
# Updating files:  75% (297/395)
# Updating files:  76% (301/395)
# Updating files:  77% (305/395)
# Updating files:  78% (309/395)
# Updating files:  79% (313/395)
# Updating files:  80% (316/395)
# Updating files:  81% (320/395)
# Updating files:  82% (324/395)
# Updating files:  83% (328/395)
# Updating files:  84% (332/395)
# Updating files:  85% (336/395)
# Updating files:  86% (340/395)
# Updating files:  87% (344/395)
# Updating files:  88% (348/395)
# Updating files:  89% (352/395)
# Updating files:  90% (356/395)
# Updating files:  91% (360/395)
# Updating files:  92% (364/395)
# Updating files:  93% (368/395)
# Updating files:  94% (372/395)
# Updating files:  95% (376/395)
# Updating files:  96% (380/395)
# Updating files:  97% (384/395)
# Updating files:  98% (388/395)
# Updating files:  99% (392/395)
# Updating files: 100% (395/395)
# Updating files: 100% (395/395), done.
# Cloning into 'pymushra'...
#  * Serving Flask app 'pymushra.service'
#  * Debug mode: on
# [    responses                          questionaire  ... responses
#         score                                  uuid  ...   comment    time
# 0           0  2560336e-cc15-4a9e-b2d1-6f97bf19b2a7  ...      None  193367
# 1           0  2560336e-cc15-4a9e-b2d1-6f97bf19b2a7  ...      None  193367
# 2           0  2560336e-cc15-4a9e-b2d1-6f97bf19b2a7  ...      None  193367
# 3           0  2560336e-cc15-4a9e-b2d1-6f97bf19b2a7  ...      None  193367
# 4           0  2560336e-cc15-4a9e-b2d1-6f97bf19b2a7  ...      None    4304
# ..        ...                                   ...  ...       ...     ...
# 559        88  588220f7-3e46-460a-9552-67bf0a5adc0d  ...      None  315703
# 560       100  588220f7-3e46-460a-9552-67bf0a5adc0d  ...      None  315703
# 561       100  588220f7-3e46-460a-9552-67bf0a5adc0d  ...      None  315703
# 562        65  588220f7-3e46-460a-9552-67bf0a5adc0d  ...      None  315703
# 563        58  588220f7-3e46-460a-9552-67bf0a5adc0d  ...      None  315703
#
# [564 rows x 10 columns]]
# [       responses          ...                         wm responses
#         stimulus comment  ...                       date     score
# 0       Lang_eng    None  ... 2025-04-30 13:28:45.610498         0
# 1        Lang_jp    None  ... 2025-04-30 13:28:45.610498         0
# 2       Lang_man    None  ... 2025-04-30 13:28:45.610498         0
# 3     Lang_canto    None  ... 2025-04-30 13:28:45.610498         0
# 4              M    None  ... 2025-04-30 13:28:45.610498         0
# ..           ...     ...  ...                        ...       ...
# 559         C3_2    None  ... 2025-05-04 16:23:38.644234        88
# 560  reference_1    None  ... 2025-05-04 16:23:38.644234       100
# 561  reference_2    None  ... 2025-05-04 16:23:38.644234       100
# 562         C4_1    None  ... 2025-05-04 16:23:38.644234        65
# 563         C4_2    None  ... 2025-05-04 16:23:38.644234        58
#
# [564 rows x 10 columns]]
# [       responses          ...                         wm responses
#         stimulus comment  ...                       date     score
# 0       Lang_eng    None  ... 2025-04-30 13:28:45.610498         0
# 1        Lang_jp    None  ... 2025-04-30 13:28:45.610498         0
# 2       Lang_man    None  ... 2025-04-30 13:28:45.610498         0
# 3     Lang_canto    None  ... 2025-04-30 13:28:45.610498         0
# 4              M    None  ... 2025-04-30 13:28:45.610498         0
# ..           ...     ...  ...                        ...       ...
# 559         C3_2    None  ... 2025-05-04 16:23:38.644234        88
# 560  reference_1    None  ... 2025-05-04 16:23:38.644234       100
# 561  reference_2    None  ... 2025-05-04 16:23:38.644234       100
# 562         C4_1    None  ... 2025-05-04 16:23:38.644234        65
# 563         C4_2    None  ... 2025-05-04 16:23:38.644234        58
#
# [564 rows x 10 columns]]
# [       responses          ...                         wm responses
#         stimulus comment  ...                       date     score
# 0       Lang_eng    None  ... 2025-04-30 13:28:45.610498         0
# 1        Lang_jp    None  ... 2025-04-30 13:28:45.610498         0
# 2       Lang_man    None  ... 2025-04-30 13:28:45.610498         0
# 3     Lang_canto    None  ... 2025-04-30 13:28:45.610498         0
# 4              M    None  ... 2025-04-30 13:28:45.610498         0
# ..           ...     ...  ...                        ...       ...
# 559         C3_2    None  ... 2025-05-04 16:23:38.644234        88
# 560  reference_1    None  ... 2025-05-04 16:23:38.644234       100
# 561  reference_2    None  ... 2025-05-04 16:23:38.644234       100
# 562         C4_1    None  ... 2025-05-04 16:23:38.644234        65
# 563         C4_2    None  ... 2025-05-04 16:23:38.644234        58
#
# [564 rows x 10 columns]]
# [                                   wm  ...
#                                config  ...                       date
# 0    configs/mushra_noloop_nowav.yaml  ... 2025-04-30 13:28:45.610498
# 1    configs/mushra_noloop_nowav.yaml  ... 2025-04-30 13:28:45.610498
# 2    configs/mushra_noloop_nowav.yaml  ... 2025-04-30 13:28:45.610498
# 3    configs/mushra_noloop_nowav.yaml  ... 2025-04-30 13:28:45.610498
# 4    configs/mushra_noloop_nowav.yaml  ... 2025-04-30 13:28:45.610498
# ..                                ...  ...                        ...
# 559  configs/mushra_noloop_nowav.yaml  ... 2025-05-04 16:23:38.644234
# 560  configs/mushra_noloop_nowav.yaml  ... 2025-05-04 16:23:38.644234
# 561  configs/mushra_noloop_nowav.yaml  ... 2025-05-04 16:23:38.644234
# 562  configs/mushra_noloop_nowav.yaml  ... 2025-05-04 16:23:38.644234
# 563  configs/mushra_noloop_nowav.yaml  ... 2025-05-04 16:23:38.644234
#
# [564 rows x 10 columns]]
# [    responses  ...                wm
#         score  ...                id
# 0           0  ...          lang_fam
# 1           0  ...          lang_fam
# 2           0  ...          lang_fam
# 3           0  ...          lang_fam
# 4           0  ...            gender
# ..        ...  ...               ...
# 559        88  ...  cantonese_test_2
# 560       100  ...  cantonese_test_2
# 561       100  ...  cantonese_test_2
# 562        65  ...  cantonese_test_2
# 563        58  ...  cantonese_test_2
#
# [564 rows x 10 columns]]
# [    responses  ...                wm
#         score  ...                id
# 0           0  ...          lang_fam
# 1           0  ...          lang_fam
# 2           0  ...          lang_fam
# 3           0  ...          lang_fam
# 4           0  ...            gender
# ..        ...  ...               ...
# 559        88  ...  cantonese_test_2
# 560       100  ...  cantonese_test_2
# 561       100  ...  cantonese_test_2
# 562        65  ...  cantonese_test_2
# 563        58  ...  cantonese_test_2
#
# [564 rows x 10 columns]]
# [       responses        ...                                wm
#         stimulus score  ...                            config                id
# 0       Lang_eng     0  ...  configs/mushra_noloop_nowav.yaml          lang_fam
# 1        Lang_jp     0  ...  configs/mushra_noloop_nowav.yaml          lang_fam
# 2       Lang_man     0  ...  configs/mushra_noloop_nowav.yaml          lang_fam
# 3     Lang_canto     0  ...  configs/mushra_noloop_nowav.yaml          lang_fam
# 4              M     0  ...  configs/mushra_noloop_nowav.yaml            gender
# ..           ...   ...  ...                               ...               ...
# 559         C3_2    88  ...  configs/mushra_noloop_nowav.yaml  cantonese_test_2
# 560  reference_1   100  ...  configs/mushra_noloop_nowav.yaml  cantonese_test_2
# 561  reference_2   100  ...  configs/mushra_noloop_nowav.yaml  cantonese_test_2
# 562         C4_1    65  ...  configs/mushra_noloop_nowav.yaml  cantonese_test_2
# 563         C4_2    58  ...  configs/mushra_noloop_nowav.yaml  cantonese_test_2
#
# [564 rows x 10 columns]]
# [                                   wm  ... responses
#                                config  ...   comment
# 0    configs/mushra_noloop_nowav.yaml  ...      None
# 1    configs/mushra_noloop_nowav.yaml  ...      None
# 2    configs/mushra_noloop_nowav.yaml  ...      None
# 3    configs/mushra_noloop_nowav.yaml  ...      None
# 4    configs/mushra_noloop_nowav.yaml  ...      None
# ..                                ...  ...       ...
# 559  configs/mushra_noloop_nowav.yaml  ...      None
# 560  configs/mushra_noloop_nowav.yaml  ...      None
# 561  configs/mushra_noloop_nowav.yaml  ...      None
# 562  configs/mushra_noloop_nowav.yaml  ...      None
# 563  configs/mushra_noloop_nowav.yaml  ...      None
#
# [564 rows x 10 columns]]
# [                                   wm  ... responses
#                                config  ...   comment
# 0    configs/mushra_noloop_nowav.yaml  ...      None
# 1    configs/mushra_noloop_nowav.yaml  ...      None
# 2    configs/mushra_noloop_nowav.yaml  ...      None
# 3    configs/mushra_noloop_nowav.yaml  ...      None
# 4    configs/mushra_noloop_nowav.yaml  ...      None
# ..                                ...  ...       ...
# 559  configs/mushra_noloop_nowav.yaml  ...      None
# 560  configs/mushra_noloop_nowav.yaml  ...      None
# 561  configs/mushra_noloop_nowav.yaml  ...      None
# 562  configs/mushra_noloop_nowav.yaml  ...      None
# 563  configs/mushra_noloop_nowav.yaml  ...      None
#
# [564 rows x 10 columns]]
# [                                   wm  ... responses
#                                config  ...   comment
# 0    configs/mushra_noloop_nowav.yaml  ...      None
# 1    configs/mushra_noloop_nowav.yaml  ...      None
# 2    configs/mushra_noloop_nowav.yaml  ...      None
# 3    configs/mushra_noloop_nowav.yaml  ...      None
# 4    configs/mushra_noloop_nowav.yaml  ...      None
# ..                                ...  ...       ...
# 559  configs/mushra_noloop_nowav.yaml  ...      None
# 560  configs/mushra_noloop_nowav.yaml  ...      None
# 561  configs/mushra_noloop_nowav.yaml  ...      None
# 562  configs/mushra_noloop_nowav.yaml  ...      None
# 563  configs/mushra_noloop_nowav.yaml  ...      None
#
# [564 rows x 10 columns]]
# [                                   wm  ... responses
#                                config  ...   comment
# 0    configs/mushra_noloop_nowav.yaml  ...      None
# 1    configs/mushra_noloop_nowav.yaml  ...      None
# 2    configs/mushra_noloop_nowav.yaml  ...      None
# 3    configs/mushra_noloop_nowav.yaml  ...      None
# 4    configs/mushra_noloop_nowav.yaml  ...      None
# ..                                ...  ...       ...
# 559  configs/mushra_noloop_nowav.yaml  ...      None
# 560  configs/mushra_noloop_nowav.yaml  ...      None
# 561  configs/mushra_noloop_nowav.yaml  ...      None
# 562  configs/mushra_noloop_nowav.yaml  ...      None
# 563  configs/mushra_noloop_nowav.yaml  ...      None
#
# [564 rows x 10 columns]]
# [61, 62, 63, 64, 65, 66, 67, 68, 69, 70]
# [                             questionaire  ...                   wm
#                                      uuid  ...                 type
# 0    2560336e-cc15-4a9e-b2d1-6f97bf19b2a7  ...  languageFamiliarity
# 1    2560336e-cc15-4a9e-b2d1-6f97bf19b2a7  ...  languageFamiliarity
# 2    2560336e-cc15-4a9e-b2d1-6f97bf19b2a7  ...  languageFamiliarity
# 3    2560336e-cc15-4a9e-b2d1-6f97bf19b2a7  ...  languageFamiliarity
# 4    2560336e-cc15-4a9e-b2d1-6f97bf19b2a7  ...               gender
# ..                                    ...  ...                  ...
# 653  82df46f9-0a36-415f-b450-e04daa63725c  ...               mushra
# 654  82df46f9-0a36-415f-b450-e04daa63725c  ...               mushra
# 655  82df46f9-0a36-415f-b450-e04daa63725c  ...               mushra
# 656  82df46f9-0a36-415f-b450-e04daa63725c  ...               mushra
# 657  82df46f9-0a36-415f-b450-e04daa63725c  ...               mushra
#
# [658 rows x 10 columns]]
# [                             questionaire  ...                   wm
#                                      uuid  ...                 type
# 0    2560336e-cc15-4a9e-b2d1-6f97bf19b2a7  ...  languageFamiliarity
# 1    2560336e-cc15-4a9e-b2d1-6f97bf19b2a7  ...  languageFamiliarity
# 2    2560336e-cc15-4a9e-b2d1-6f97bf19b2a7  ...  languageFamiliarity
# 3    2560336e-cc15-4a9e-b2d1-6f97bf19b2a7  ...  languageFamiliarity
# 4    2560336e-cc15-4a9e-b2d1-6f97bf19b2a7  ...               gender
# ..                                    ...  ...                  ...
# 653  82df46f9-0a36-415f-b450-e04daa63725c  ...               mushra
# 654  82df46f9-0a36-415f-b450-e04daa63725c  ...               mushra
# 655  82df46f9-0a36-415f-b450-e04daa63725c  ...               mushra
# 656  82df46f9-0a36-415f-b450-e04daa63725c  ...               mushra
# 657  82df46f9-0a36-415f-b450-e04daa63725c  ...               mushra
#
# [658 rows x 10 columns]]
# [                      wm                       ... responses                         wm
#                   testId                 type  ...     score                       date
# 0    mushra_noloop_nowav  languageFamiliarity  ...         0 2025-04-30 13:28:45.610498
# 1    mushra_noloop_nowav  languageFamiliarity  ...         0 2025-04-30 13:28:45.610498
# 2    mushra_noloop_nowav  languageFamiliarity  ...         0 2025-04-30 13:28:45.610498
# 3    mushra_noloop_nowav  languageFamiliarity  ...         0 2025-04-30 13:28:45.610498
# 4    mushra_noloop_nowav               gender  ...         0 2025-04-30 13:28:45.610498
# ..                   ...                  ...  ...       ...                        ...
# 653  mushra_noloop_nowav               mushra  ...        30 2025-05-04 21:15:54.466993
# 654  mushra_noloop_nowav               mushra  ...         0 2025-05-04 21:15:54.466993
# 655  mushra_noloop_nowav               mushra  ...        70 2025-05-04 21:15:54.466993
# 656  mushra_noloop_nowav               mushra  ...       100 2025-05-04 21:15:54.466993
# 657  mushra_noloop_nowav               mushra  ...       100 2025-05-04 21:15:54.466993
#
# [658 rows x 10 columns]]
# [                      wm                       ... responses                         wm
#                   testId                 type  ...     score                       date
# 0    mushra_noloop_nowav  languageFamiliarity  ...         0 2025-04-30 13:28:45.610498
# 1    mushra_noloop_nowav  languageFamiliarity  ...         0 2025-04-30 13:28:45.610498
# 2    mushra_noloop_nowav  languageFamiliarity  ...         0 2025-04-30 13:28:45.610498
# 3    mushra_noloop_nowav  languageFamiliarity  ...         0 2025-04-30 13:28:45.610498
# 4    mushra_noloop_nowav               gender  ...         0 2025-04-30 13:28:45.610498
# ..                   ...                  ...  ...       ...                        ...
# 653  mushra_noloop_nowav               mushra  ...        30 2025-05-04 21:15:54.466993
# 654  mushra_noloop_nowav               mushra  ...         0 2025-05-04 21:15:54.466993
# 655  mushra_noloop_nowav               mushra  ...        70 2025-05-04 21:15:54.466993
# 656  mushra_noloop_nowav               mushra  ...       100 2025-05-04 21:15:54.466993
# 657  mushra_noloop_nowav               mushra  ...       100 2025-05-04 21:15:54.466993
#
# [658 rows x 10 columns]]
# [                                   wm  ...    responses
#                                config  ...     stimulus
# 0    configs/mushra_noloop_nowav.yaml  ...     Lang_eng
# 1    configs/mushra_noloop_nowav.yaml  ...      Lang_jp
# 2    configs/mushra_noloop_nowav.yaml  ...     Lang_man
# 3    configs/mushra_noloop_nowav.yaml  ...   Lang_canto
# 4    configs/mushra_noloop_nowav.yaml  ...            M
# ..                                ...  ...          ...
# 653  configs/mushra_noloop_nowav.yaml  ...         C4_2
# 654  configs/mushra_noloop_nowav.yaml  ...         C3_1
# 655  configs/mushra_noloop_nowav.yaml  ...         C3_2
# 656  configs/mushra_noloop_nowav.yaml  ...  reference_1
# 657  configs/mushra_noloop_nowav.yaml  ...  reference_2
#
# [658 rows x 10 columns]]
# [                                   wm  ...    responses
#                                config  ...     stimulus
# 0    configs/mushra_noloop_nowav.yaml  ...     Lang_eng
# 1    configs/mushra_noloop_nowav.yaml  ...      Lang_jp
# 2    configs/mushra_noloop_nowav.yaml  ...     Lang_man
# 3    configs/mushra_noloop_nowav.yaml  ...   Lang_canto
# 4    configs/mushra_noloop_nowav.yaml  ...            M
# ..                                ...  ...          ...
# 653  configs/mushra_noloop_nowav.yaml  ...         C4_2
# 654  configs/mushra_noloop_nowav.yaml  ...         C3_1
# 655  configs/mushra_noloop_nowav.yaml  ...         C3_2
# 656  configs/mushra_noloop_nowav.yaml  ...  reference_1
# 657  configs/mushra_noloop_nowav.yaml  ...  reference_2
#
# [658 rows x 10 columns]]
# [71, 72, 73, 74, 75, 76, 77, 78, 79, 80]
# [                                   wm  ...   responses
#                                config  ...    stimulus
# 0    configs/mushra_noloop_nowav.yaml  ...    Lang_eng
# 1    configs/mushra_noloop_nowav.yaml  ...     Lang_jp
# 2    configs/mushra_noloop_nowav.yaml  ...    Lang_man
# 3    configs/mushra_noloop_nowav.yaml  ...  Lang_canto
# 4    configs/mushra_noloop_nowav.yaml  ...           M
# ..                                ...  ...         ...
# 747  configs/mushra_noloop_nowav.yaml  ...        C4_2
# 748  configs/mushra_noloop_nowav.yaml  ...        C2_1
# 749  configs/mushra_noloop_nowav.yaml  ...        C2_2
# 750  configs/mushra_noloop_nowav.yaml  ...        C1_1
# 751  configs/mushra_noloop_nowav.yaml  ...        C1_2
#
# [752 rows x 10 columns]]
# [       responses                         wm  ...                      responses
#         stimulus                       date  ...               testId     score
# 0       Lang_eng 2025-04-30 13:28:45.610498  ...  mushra_noloop_nowav         0
# 1        Lang_jp 2025-04-30 13:28:45.610498  ...  mushra_noloop_nowav         0
# 2       Lang_man 2025-04-30 13:28:45.610498  ...  mushra_noloop_nowav         0
# 3     Lang_canto 2025-04-30 13:28:45.610498  ...  mushra_noloop_nowav         0
# 4              M 2025-04-30 13:28:45.610498  ...  mushra_noloop_nowav         0
# ..           ...                        ...  ...                  ...       ...
# 653         C4_2 2025-05-04 21:15:54.466993  ...  mushra_noloop_nowav        30
# 654         C3_1 2025-05-04 21:15:54.466993  ...  mushra_noloop_nowav         0
# 655         C3_2 2025-05-04 21:15:54.466993  ...  mushra_noloop_nowav        70
# 656  reference_1 2025-05-04 21:15:54.466993  ...  mushra_noloop_nowav       100
# 657  reference_2 2025-05-04 21:15:54.466993  ...  mushra_noloop_nowav       100
#
# [658 rows x 10 columns]]
# [                            wm responses  ...
#                           date     score  ...    time     stimulus
# 0   2025-04-30 13:28:45.610498         0  ...  193367     Lang_eng
# 1   2025-04-30 13:28:45.610498         0  ...  193367      Lang_jp
# 2   2025-04-30 13:28:45.610498         0  ...  193367     Lang_man
# 3   2025-04-30 13:28:45.610498         0  ...  193367   Lang_canto
# 4   2025-04-30 13:28:45.610498         0  ...    4304            M
# ..                         ...       ...  ...     ...          ...
# 653 2025-05-04 21:15:54.466993        30  ...  117490         C4_2
# 654 2025-05-04 21:15:54.466993         0  ...  117490         C3_1
# 655 2025-05-04 21:15:54.466993        70  ...  117490         C3_2
# 656 2025-05-04 21:15:54.466993       100  ...  117490  reference_1
# 657 2025-05-04 21:15:54.466993       100  ...  117490  reference_2
#
# [658 rows x 10 columns]]
# [71, 72, 73, 74, 75, 76, 77, 78, 79, 80]
# [                            wm responses  ...
#                           date     score  ...    time    stimulus
# 0   2025-04-30 13:28:45.610498         0  ...  193367    Lang_eng
# 1   2025-04-30 13:28:45.610498         0  ...  193367     Lang_jp
# 2   2025-04-30 13:28:45.610498         0  ...  193367    Lang_man
# 3   2025-04-30 13:28:45.610498         0  ...  193367  Lang_canto
# 4   2025-04-30 13:28:45.610498         0  ...    4304           M
# ..                         ...       ...  ...     ...         ...
# 747 2025-05-04 23:48:49.429693        25  ...   47868        C4_2
# 748 2025-05-04 23:48:49.429693        25  ...   47868        C1_1
# 749 2025-05-04 23:48:49.429693        73  ...   47868        C1_2
# 750 2025-05-04 23:48:49.429693        84  ...   47868        C2_1
# 751 2025-05-04 23:48:49.429693        84  ...   47868        C2_2
#
# [752 rows x 10 columns]]
# [                      wm  ...
#                   testId  ...                id
# 0    mushra_noloop_nowav  ...          lang_fam
# 1    mushra_noloop_nowav  ...          lang_fam
# 2    mushra_noloop_nowav  ...          lang_fam
# 3    mushra_noloop_nowav  ...          lang_fam
# 4    mushra_noloop_nowav  ...            gender
# ..                   ...  ...               ...
# 747  mushra_noloop_nowav  ...  cantonese_test_2
# 748  mushra_noloop_nowav  ...  cantonese_test_2
# 749  mushra_noloop_nowav  ...  cantonese_test_2
# 750  mushra_noloop_nowav  ...  cantonese_test_2
# 751  mushra_noloop_nowav  ...  cantonese_test_2
#
# [752 rows x 10 columns]]
# [                                   wm  ...
#                                config  ...                       date
# 0    configs/mushra_noloop_nowav.yaml  ... 2025-04-30 13:28:45.610498
# 1    configs/mushra_noloop_nowav.yaml  ... 2025-04-30 13:28:45.610498
# 2    configs/mushra_noloop_nowav.yaml  ... 2025-04-30 13:28:45.610498
# 3    configs/mushra_noloop_nowav.yaml  ... 2025-04-30 13:28:45.610498
# 4    configs/mushra_noloop_nowav.yaml  ... 2025-04-30 13:28:45.610498
# ..                                ...  ...                        ...
# 747  configs/mushra_noloop_nowav.yaml  ... 2025-05-04 23:48:49.429693
# 748  configs/mushra_noloop_nowav.yaml  ... 2025-05-04 23:48:49.429693
# 749  configs/mushra_noloop_nowav.yaml  ... 2025-05-04 23:48:49.429693
# 750  configs/mushra_noloop_nowav.yaml  ... 2025-05-04 23:48:49.429693
# 751  configs/mushra_noloop_nowav.yaml  ... 2025-05-04 23:48:49.429693
#
# [752 rows x 10 columns]]
# [81, 82, 83, 84, 85, 86, 87, 88, 89, 90]
# [91, 92, 93, 94, 95, 96, 97, 98, 99, 100]
# [       responses                   wm  ... responses
#         stimulus                 type  ...     score comment
# 0       Lang_eng  languageFamiliarity  ...         0    None
# 1        Lang_jp  languageFamiliarity  ...         0    None
# 2       Lang_man  languageFamiliarity  ...         0    None
# 3     Lang_canto  languageFamiliarity  ...         0    None
# 4              M               gender  ...         0    None
# ..           ...                  ...  ...       ...     ...
# 935  reference_2               mushra  ...        81    None
# 936         C1_1               mushra  ...        41    None
# 937         C1_2               mushra  ...        68    None
# 938         C4_1               mushra  ...        16    None
# 939         C4_2               mushra  ...        41    None
#
# [940 rows x 10 columns]]
# [       responses                   wm  ... responses
#         stimulus                 type  ...     score comment
# 0       Lang_eng  languageFamiliarity  ...         0    None
# 1        Lang_jp  languageFamiliarity  ...         0    None
# 2       Lang_man  languageFamiliarity  ...         0    None
# 3     Lang_canto  languageFamiliarity  ...         0    None
# 4              M               gender  ...         0    None
# ..           ...                  ...  ...       ...     ...
# 935  reference_2               mushra  ...        81    None
# 936         C1_1               mushra  ...        41    None
# 937         C1_2               mushra  ...        68    None
# 938         C4_1               mushra  ...        16    None
# 939         C4_2               mushra  ...        41    None
#
# [940 rows x 10 columns]]
# [    responses  ...                                wm
#         score  ...                            config
# 0           0  ...  configs/mushra_noloop_nowav.yaml
# 1           0  ...  configs/mushra_noloop_nowav.yaml
# 2           0  ...  configs/mushra_noloop_nowav.yaml
# 3           0  ...  configs/mushra_noloop_nowav.yaml
# 4           0  ...  configs/mushra_noloop_nowav.yaml
# ..        ...  ...                               ...
# 935        81  ...  configs/mushra_noloop_nowav.yaml
# 936        41  ...  configs/mushra_noloop_nowav.yaml
# 937        68  ...  configs/mushra_noloop_nowav.yaml
# 938        16  ...  configs/mushra_noloop_nowav.yaml
# 939        41  ...  configs/mushra_noloop_nowav.yaml
#
# [940 rows x 10 columns]]
# [    responses  ...                                wm
#         score  ...                            config
# 0           0  ...  configs/mushra_noloop_nowav.yaml
# 1           0  ...  configs/mushra_noloop_nowav.yaml
# 2           0  ...  configs/mushra_noloop_nowav.yaml
# 3           0  ...  configs/mushra_noloop_nowav.yaml
# 4           0  ...  configs/mushra_noloop_nowav.yaml
# ..        ...  ...                               ...
# 935        81  ...  configs/mushra_noloop_nowav.yaml
# 936        41  ...  configs/mushra_noloop_nowav.yaml
# 937        68  ...  configs/mushra_noloop_nowav.yaml
# 938        16  ...  configs/mushra_noloop_nowav.yaml
# 939        41  ...  configs/mushra_noloop_nowav.yaml
#
# [940 rows x 10 columns]]
# [    responses  ...                                wm
#         score  ...                            config
# 0           0  ...  configs/mushra_noloop_nowav.yaml
# 1           0  ...  configs/mushra_noloop_nowav.yaml
# 2           0  ...  configs/mushra_noloop_nowav.yaml
# 3           0  ...  configs/mushra_noloop_nowav.yaml
# 4           0  ...  configs/mushra_noloop_nowav.yaml
# ..        ...  ...                               ...
# 935        81  ...  configs/mushra_noloop_nowav.yaml
# 936        41  ...  configs/mushra_noloop_nowav.yaml
# 937        68  ...  configs/mushra_noloop_nowav.yaml
# 938        16  ...  configs/mushra_noloop_nowav.yaml
# 939        41  ...  configs/mushra_noloop_nowav.yaml
#
# [940 rows x 10 columns]]
# [    responses               ...                wm
#       comment     stimulus  ...                id                            config
# 0        None     Lang_eng  ...          lang_fam  configs/mushra_noloop_nowav.yaml
# 1        None      Lang_jp  ...          lang_fam  configs/mushra_noloop_nowav.yaml
# 2        None     Lang_man  ...          lang_fam  configs/mushra_noloop_nowav.yaml
# 3        None   Lang_canto  ...          lang_fam  configs/mushra_noloop_nowav.yaml
# 4        None            M  ...            gender  configs/mushra_noloop_nowav.yaml
# ..        ...          ...  ...               ...                               ...
# 935      None  reference_2  ...  cantonese_test_2  configs/mushra_noloop_nowav.yaml
# 936      None         C1_1  ...  cantonese_test_2  configs/mushra_noloop_nowav.yaml
# 937      None         C1_2  ...  cantonese_test_2  configs/mushra_noloop_nowav.yaml
# 938      None         C4_1  ...  cantonese_test_2  configs/mushra_noloop_nowav.yaml
# 939      None         C4_2  ...  cantonese_test_2  configs/mushra_noloop_nowav.yaml
#
# [940 rows x 10 columns]]
# [    responses               ...                wm
#       comment     stimulus  ...                id                            config
# 0        None     Lang_eng  ...          lang_fam  configs/mushra_noloop_nowav.yaml
# 1        None      Lang_jp  ...          lang_fam  configs/mushra_noloop_nowav.yaml
# 2        None     Lang_man  ...          lang_fam  configs/mushra_noloop_nowav.yaml
# 3        None   Lang_canto  ...          lang_fam  configs/mushra_noloop_nowav.yaml
# 4        None            M  ...            gender  configs/mushra_noloop_nowav.yaml
# ..        ...          ...  ...               ...                               ...
# 935      None  reference_2  ...  cantonese_test_2  configs/mushra_noloop_nowav.yaml
# 936      None         C1_1  ...  cantonese_test_2  configs/mushra_noloop_nowav.yaml
# 937      None         C1_2  ...  cantonese_test_2  configs/mushra_noloop_nowav.yaml
# 938      None         C4_1  ...  cantonese_test_2  configs/mushra_noloop_nowav.yaml
# 939      None         C4_2  ...  cantonese_test_2  configs/mushra_noloop_nowav.yaml
#
# [940 rows x 10 columns]]
# [                                   wm  ...
#                                config  ...                id
# 0    configs/mushra_noloop_nowav.yaml  ...          lang_fam
# 1    configs/mushra_noloop_nowav.yaml  ...          lang_fam
# 2    configs/mushra_noloop_nowav.yaml  ...          lang_fam
# 3    configs/mushra_noloop_nowav.yaml  ...          lang_fam
# 4    configs/mushra_noloop_nowav.yaml  ...            gender
# ..                                ...  ...               ...
# 935  configs/mushra_noloop_nowav.yaml  ...  cantonese_test_2
# 936  configs/mushra_noloop_nowav.yaml  ...  cantonese_test_2
# 937  configs/mushra_noloop_nowav.yaml  ...  cantonese_test_2
# 938  configs/mushra_noloop_nowav.yaml  ...  cantonese_test_2
# 939  configs/mushra_noloop_nowav.yaml  ...  cantonese_test_2
#
# [940 rows x 10 columns]]
# [                                   wm  ...
#                                config  ...                id
# 0    configs/mushra_noloop_nowav.yaml  ...          lang_fam
# 1    configs/mushra_noloop_nowav.yaml  ...          lang_fam
# 2    configs/mushra_noloop_nowav.yaml  ...          lang_fam
# 3    configs/mushra_noloop_nowav.yaml  ...          lang_fam
# 4    configs/mushra_noloop_nowav.yaml  ...            gender
# ..                                ...  ...               ...
# 935  configs/mushra_noloop_nowav.yaml  ...  cantonese_test_2
# 936  configs/mushra_noloop_nowav.yaml  ...  cantonese_test_2
# 937  configs/mushra_noloop_nowav.yaml  ...  cantonese_test_2
# 938  configs/mushra_noloop_nowav.yaml  ...  cantonese_test_2
# 939  configs/mushra_noloop_nowav.yaml  ...  cantonese_test_2
#
# [940 rows x 10 columns]]
# [                                   wm  ...
#                                config  ...                id
# 0    configs/mushra_noloop_nowav.yaml  ...          lang_fam
# 1    configs/mushra_noloop_nowav.yaml  ...          lang_fam
# 2    configs/mushra_noloop_nowav.yaml  ...          lang_fam
# 3    configs/mushra_noloop_nowav.yaml  ...          lang_fam
# 4    configs/mushra_noloop_nowav.yaml  ...            gender
# ..                                ...  ...               ...
# 935  configs/mushra_noloop_nowav.yaml  ...  cantonese_test_2
# 936  configs/mushra_noloop_nowav.yaml  ...  cantonese_test_2
# 937  configs/mushra_noloop_nowav.yaml  ...  cantonese_test_2
# 938  configs/mushra_noloop_nowav.yaml  ...  cantonese_test_2
# 939  configs/mushra_noloop_nowav.yaml  ...  cantonese_test_2
#
# [940 rows x 10 columns]]
# [                                   wm  ...
#                                config  ...                id
# 0    configs/mushra_noloop_nowav.yaml  ...          lang_fam
# 1    configs/mushra_noloop_nowav.yaml  ...          lang_fam
# 2    configs/mushra_noloop_nowav.yaml  ...          lang_fam
# 3    configs/mushra_noloop_nowav.yaml  ...          lang_fam
# 4    configs/mushra_noloop_nowav.yaml  ...            gender
# ..                                ...  ...               ...
# 935  configs/mushra_noloop_nowav.yaml  ...  cantonese_test_2
# 936  configs/mushra_noloop_nowav.yaml  ...  cantonese_test_2
# 937  configs/mushra_noloop_nowav.yaml  ...  cantonese_test_2
# 938  configs/mushra_noloop_nowav.yaml  ...  cantonese_test_2
# 939  configs/mushra_noloop_nowav.yaml  ...  cantonese_test_2
#
# [940 rows x 10 columns]]
# [                                   wm  ...
#                                config  ...                id
# 0    configs/mushra_noloop_nowav.yaml  ...          lang_fam
# 1    configs/mushra_noloop_nowav.yaml  ...          lang_fam
# 2    configs/mushra_noloop_nowav.yaml  ...          lang_fam
# 3    configs/mushra_noloop_nowav.yaml  ...          lang_fam
# 4    configs/mushra_noloop_nowav.yaml  ...            gender
# ..                                ...  ...               ...
# 935  configs/mushra_noloop_nowav.yaml  ...  cantonese_test_2
# 936  configs/mushra_noloop_nowav.yaml  ...  cantonese_test_2
# 937  configs/mushra_noloop_nowav.yaml  ...  cantonese_test_2
# 938  configs/mushra_noloop_nowav.yaml  ...  cantonese_test_2
# 939  configs/mushra_noloop_nowav.yaml  ...  cantonese_test_2
#
# [940 rows x 10 columns]]
# [                                   wm  ...
#                                config  ...                id
# 0    configs/mushra_noloop_nowav.yaml  ...          lang_fam
# 1    configs/mushra_noloop_nowav.yaml  ...          lang_fam
# 2    configs/mushra_noloop_nowav.yaml  ...          lang_fam
# 3    configs/mushra_noloop_nowav.yaml  ...          lang_fam
# 4    configs/mushra_noloop_nowav.yaml  ...            gender
# ..                                ...  ...               ...
# 935  configs/mushra_noloop_nowav.yaml  ...  cantonese_test_2
# 936  configs/mushra_noloop_nowav.yaml  ...  cantonese_test_2
# 937  configs/mushra_noloop_nowav.yaml  ...  cantonese_test_2
# 938  configs/mushra_noloop_nowav.yaml  ...  cantonese_test_2
# 939  configs/mushra_noloop_nowav.yaml  ...  cantonese_test_2
#
# [940 rows x 10 columns]]
# [                                   wm  ...
#                                config  ...                id
# 0    configs/mushra_noloop_nowav.yaml  ...          lang_fam
# 1    configs/mushra_noloop_nowav.yaml  ...          lang_fam
# 2    configs/mushra_noloop_nowav.yaml  ...          lang_fam
# 3    configs/mushra_noloop_nowav.yaml  ...          lang_fam
# 4    configs/mushra_noloop_nowav.yaml  ...            gender
# ..                                ...  ...               ...
# 935  configs/mushra_noloop_nowav.yaml  ...  cantonese_test_2
# 936  configs/mushra_noloop_nowav.yaml  ...  cantonese_test_2
# 937  configs/mushra_noloop_nowav.yaml  ...  cantonese_test_2
# 938  configs/mushra_noloop_nowav.yaml  ...  cantonese_test_2
# 939  configs/mushra_noloop_nowav.yaml  ...  cantonese_test_2
#
# [940 rows x 10 columns]]
# [                                   wm  ...
#                                config  ...                id
# 0    configs/mushra_noloop_nowav.yaml  ...          lang_fam
# 1    configs/mushra_noloop_nowav.yaml  ...          lang_fam
# 2    configs/mushra_noloop_nowav.yaml  ...          lang_fam
# 3    configs/mushra_noloop_nowav.yaml  ...          lang_fam
# 4    configs/mushra_noloop_nowav.yaml  ...            gender
# ..                                ...  ...               ...
# 935  configs/mushra_noloop_nowav.yaml  ...  cantonese_test_2
# 936  configs/mushra_noloop_nowav.yaml  ...  cantonese_test_2
# 937  configs/mushra_noloop_nowav.yaml  ...  cantonese_test_2
# 938  configs/mushra_noloop_nowav.yaml  ...  cantonese_test_2
# 939  configs/mushra_noloop_nowav.yaml  ...  cantonese_test_2
#
# [940 rows x 10 columns]]
# [                      wm  ...    responses
#                     type  ...     stimulus
# 0    languageFamiliarity  ...     Lang_eng
# 1    languageFamiliarity  ...      Lang_jp
# 2    languageFamiliarity  ...     Lang_man
# 3    languageFamiliarity  ...   Lang_canto
# 4                 gender  ...            M
# ..                   ...  ...          ...
# 935               mushra  ...  reference_2
# 936               mushra  ...         C1_1
# 937               mushra  ...         C1_2
# 938               mushra  ...         C4_1
# 939               mushra  ...         C4_2
#
# [940 rows x 10 columns]]
# [                      wm  ...    responses
#                     type  ...     stimulus
# 0    languageFamiliarity  ...     Lang_eng
# 1    languageFamiliarity  ...      Lang_jp
# 2    languageFamiliarity  ...     Lang_man
# 3    languageFamiliarity  ...   Lang_canto
# 4                 gender  ...            M
# ..                   ...  ...          ...
# 935               mushra  ...  reference_2
# 936               mushra  ...         C1_1
# 937               mushra  ...         C1_2
# 938               mushra  ...         C4_1
# 939               mushra  ...         C4_2
#
# [940 rows x 10 columns]]
# [                      wm  ...    responses
#                     type  ...     stimulus
# 0    languageFamiliarity  ...     Lang_eng
# 1    languageFamiliarity  ...      Lang_jp
# 2    languageFamiliarity  ...     Lang_man
# 3    languageFamiliarity  ...   Lang_canto
# 4                 gender  ...            M
# ..                   ...  ...          ...
# 935               mushra  ...  reference_2
# 936               mushra  ...         C1_1
# 937               mushra  ...         C1_2
# 938               mushra  ...         C4_1
# 939               mushra  ...         C4_2
#
# [940 rows x 10 columns]]
# [                      wm  ... responses
#                   testId  ...      time
# 0    mushra_noloop_nowav  ...    193367
# 1    mushra_noloop_nowav  ...    193367
# 2    mushra_noloop_nowav  ...    193367
# 3    mushra_noloop_nowav  ...    193367
# 4    mushra_noloop_nowav  ...      4304
# ..                   ...  ...       ...
# 935  mushra_noloop_nowav  ...    141831
# 936  mushra_noloop_nowav  ...    141831
# 937  mushra_noloop_nowav  ...    141831
# 938  mushra_noloop_nowav  ...    141831
# 939  mushra_noloop_nowav  ...    141831
#
# [940 rows x 10 columns]]
# [                      wm  ... responses
#                   testId  ...      time
# 0    mushra_noloop_nowav  ...    193367
# 1    mushra_noloop_nowav  ...    193367
# 2    mushra_noloop_nowav  ...    193367
# 3    mushra_noloop_nowav  ...    193367
# 4    mushra_noloop_nowav  ...      4304
# ..                   ...  ...       ...
# 935  mushra_noloop_nowav  ...    141831
# 936  mushra_noloop_nowav  ...    141831
# 937  mushra_noloop_nowav  ...    141831
# 938  mushra_noloop_nowav  ...    141831
# 939  mushra_noloop_nowav  ...    141831
#
# [940 rows x 10 columns]]
# [                      wm  ... responses
#                   testId  ...      time
# 0    mushra_noloop_nowav  ...    193367
# 1    mushra_noloop_nowav  ...    193367
# 2    mushra_noloop_nowav  ...    193367
# 3    mushra_noloop_nowav  ...    193367
# 4    mushra_noloop_nowav  ...      4304
# ..                   ...  ...       ...
# 935  mushra_noloop_nowav  ...    141831
# 936  mushra_noloop_nowav  ...    141831
# 937  mushra_noloop_nowav  ...    141831
# 938  mushra_noloop_nowav  ...    141831
# 939  mushra_noloop_nowav  ...    141831
#
# [940 rows x 10 columns]]
# [                      wm  ... responses
#                   testId  ...      time
# 0    mushra_noloop_nowav  ...    193367
# 1    mushra_noloop_nowav  ...    193367
# 2    mushra_noloop_nowav  ...    193367
# 3    mushra_noloop_nowav  ...    193367
# 4    mushra_noloop_nowav  ...      4304
# ..                   ...  ...       ...
# 935  mushra_noloop_nowav  ...    141831
# 936  mushra_noloop_nowav  ...    141831
# 937  mushra_noloop_nowav  ...    141831
# 938  mushra_noloop_nowav  ...    141831
# 939  mushra_noloop_nowav  ...    141831
#
# [940 rows x 10 columns]]
# [                      wm  ... responses
#                   testId  ...      time
# 0    mushra_noloop_nowav  ...    193367
# 1    mushra_noloop_nowav  ...    193367
# 2    mushra_noloop_nowav  ...    193367
# 3    mushra_noloop_nowav  ...    193367
# 4    mushra_noloop_nowav  ...      4304
# ..                   ...  ...       ...
# 935  mushra_noloop_nowav  ...    141831
# 936  mushra_noloop_nowav  ...    141831
# 937  mushra_noloop_nowav  ...    141831
# 938  mushra_noloop_nowav  ...    141831
# 939  mushra_noloop_nowav  ...    141831
#
# [940 rows x 10 columns]]
# [    responses  ...                         wm
#         score  ...                       date
# 0           0  ... 2025-04-30 13:28:45.610498
# 1           0  ... 2025-04-30 13:28:45.610498
# 2           0  ... 2025-04-30 13:28:45.610498
# 3           0  ... 2025-04-30 13:28:45.610498
# 4           0  ... 2025-04-30 13:28:45.610498
# ..        ...  ...                        ...
# 935        81  ... 2025-05-05 05:45:48.373162
# 936        41  ... 2025-05-05 05:45:48.373162
# 937        68  ... 2025-05-05 05:45:48.373162
# 938        16  ... 2025-05-05 05:45:48.373162
# 939        41  ... 2025-05-05 05:45:48.373162
#
# [940 rows x 10 columns]]
# [    responses  ...                         wm
#         score  ...                       date
# 0           0  ... 2025-04-30 13:28:45.610498
# 1           0  ... 2025-04-30 13:28:45.610498
# 2           0  ... 2025-04-30 13:28:45.610498
# 3           0  ... 2025-04-30 13:28:45.610498
# 4           0  ... 2025-04-30 13:28:45.610498
# ..        ...  ...                        ...
# 935        81  ... 2025-05-05 05:45:48.373162
# 936        41  ... 2025-05-05 05:45:48.373162
# 937        68  ... 2025-05-05 05:45:48.373162
# 938        16  ... 2025-05-05 05:45:48.373162
# 939        41  ... 2025-05-05 05:45:48.373162
#
# [940 rows x 10 columns]]
# [101, 102, 103, 104, 105, 106, 107, 108, 109, 110]
# [     responses  ...                         wm
#          score  ...                       date
# 0            0  ... 2025-04-30 13:28:45.610498
# 1            0  ... 2025-04-30 13:28:45.610498
# 2            0  ... 2025-04-30 13:28:45.610498
# 3            0  ... 2025-04-30 13:28:45.610498
# 4            0  ... 2025-04-30 13:28:45.610498
# ...        ...  ...                        ...
# 1029        50  ... 2025-05-05 17:15:49.916212
# 1030        44  ... 2025-05-05 17:15:49.916212
# 1031        24  ... 2025-05-05 17:15:49.916212
# 1032        77  ... 2025-05-05 17:15:49.916212
# 1033        76  ... 2025-05-05 17:15:49.916212
#
# [1034 rows x 10 columns]]
# [                    wm  ...                          questionaire
#                     id  ...                                  uuid
# 0             lang_fam  ...  2560336e-cc15-4a9e-b2d1-6f97bf19b2a7
# 1             lang_fam  ...  2560336e-cc15-4a9e-b2d1-6f97bf19b2a7
# 2             lang_fam  ...  2560336e-cc15-4a9e-b2d1-6f97bf19b2a7
# 3             lang_fam  ...  2560336e-cc15-4a9e-b2d1-6f97bf19b2a7
# 4               gender  ...  2560336e-cc15-4a9e-b2d1-6f97bf19b2a7
# ...                ...  ...                                   ...
# 1029  cantonese_test_2  ...  c7af4618-3c64-428a-9578-62067fa6adfc
# 1030  cantonese_test_2  ...  c7af4618-3c64-428a-9578-62067fa6adfc
# 1031  cantonese_test_2  ...  c7af4618-3c64-428a-9578-62067fa6adfc
# 1032  cantonese_test_2  ...  c7af4618-3c64-428a-9578-62067fa6adfc
# 1033  cantonese_test_2  ...  c7af4618-3c64-428a-9578-62067fa6adfc
#
# [1034 rows x 10 columns]]
# [                                    wm  ... responses
#                                 config  ...   comment
# 0     configs/mushra_noloop_nowav.yaml  ...      None
# 1     configs/mushra_noloop_nowav.yaml  ...      None
# 2     configs/mushra_noloop_nowav.yaml  ...      None
# 3     configs/mushra_noloop_nowav.yaml  ...      None
# 4     configs/mushra_noloop_nowav.yaml  ...      None
# ...                                ...  ...       ...
# 1029  configs/mushra_noloop_nowav.yaml  ...      None
# 1030  configs/mushra_noloop_nowav.yaml  ...      None
# 1031  configs/mushra_noloop_nowav.yaml  ...      None
# 1032  configs/mushra_noloop_nowav.yaml  ...      None
# 1033  configs/mushra_noloop_nowav.yaml  ...      None
#
# [1034 rows x 10 columns]]
# [                                    wm  ... responses
#                                 config  ...   comment
# 0     configs/mushra_noloop_nowav.yaml  ...      None
# 1     configs/mushra_noloop_nowav.yaml  ...      None
# 2     configs/mushra_noloop_nowav.yaml  ...      None
# 3     configs/mushra_noloop_nowav.yaml  ...      None
# 4     configs/mushra_noloop_nowav.yaml  ...      None
# ...                                ...  ...       ...
# 1029  configs/mushra_noloop_nowav.yaml  ...      None
# 1030  configs/mushra_noloop_nowav.yaml  ...      None
# 1031  configs/mushra_noloop_nowav.yaml  ...      None
# 1032  configs/mushra_noloop_nowav.yaml  ...      None
# 1033  configs/mushra_noloop_nowav.yaml  ...      None
#
# [1034 rows x 10 columns]]
# [     responses                wm  ...                         responses
#        comment                id  ...                 type     stimulus
# 0         None          lang_fam  ...  languageFamiliarity     Lang_eng
# 1         None          lang_fam  ...  languageFamiliarity      Lang_jp
# 2         None          lang_fam  ...  languageFamiliarity     Lang_man
# 3         None          lang_fam  ...  languageFamiliarity   Lang_canto
# 4         None            gender  ...               gender            M
# ...        ...               ...  ...                  ...          ...
# 1029      None  cantonese_test_2  ...               mushra         C3_2
# 1030      None  cantonese_test_2  ...               mushra         C4_1
# 1031      None  cantonese_test_2  ...               mushra         C4_2
# 1032      None  cantonese_test_2  ...               mushra  reference_1
# 1033      None  cantonese_test_2  ...               mushra  reference_2
#
# [1034 rows x 10 columns]]
# [     responses                wm  ...                         responses
#        comment                id  ...                 type     stimulus
# 0         None          lang_fam  ...  languageFamiliarity     Lang_eng
# 1         None          lang_fam  ...  languageFamiliarity      Lang_jp
# 2         None          lang_fam  ...  languageFamiliarity     Lang_man
# 3         None          lang_fam  ...  languageFamiliarity   Lang_canto
# 4         None            gender  ...               gender            M
# ...        ...               ...  ...                  ...          ...
# 1029      None  cantonese_test_2  ...               mushra         C3_2
# 1030      None  cantonese_test_2  ...               mushra         C4_1
# 1031      None  cantonese_test_2  ...               mushra         C4_2
# 1032      None  cantonese_test_2  ...               mushra  reference_1
# 1033      None  cantonese_test_2  ...               mushra  reference_2
#
# [1034 rows x 10 columns]]
# [     responses                wm  ...                         responses
#        comment                id  ...                 type     stimulus
# 0         None          lang_fam  ...  languageFamiliarity     Lang_eng
# 1         None          lang_fam  ...  languageFamiliarity      Lang_jp
# 2         None          lang_fam  ...  languageFamiliarity     Lang_man
# 3         None          lang_fam  ...  languageFamiliarity   Lang_canto
# 4         None            gender  ...               gender            M
# ...        ...               ...  ...                  ...          ...
# 1029      None  cantonese_test_2  ...               mushra         C3_2
# 1030      None  cantonese_test_2  ...               mushra         C4_1
# 1031      None  cantonese_test_2  ...               mushra         C4_2
# 1032      None  cantonese_test_2  ...               mushra  reference_1
# ...
# 127.0.0.1 - - [06/May/2025 01:35:37] "GET /configs/resources/audio/normalised_IN_K.wav HTTP/1.1" 304 -
# 127.0.0.1 - - [06/May/2025 01:35:37] "GET /configs/resources/audio/normalised_TianHou_david.wav HTTP/1.1" 304 -
# 127.0.0.1 - - [06/May/2025 01:35:37] "GET /configs/resources/audio/normalised_39_suno.wav HTTP/1.1" 304 -
# 127.0.0.1 - - [06/May/2025 01:35:37] "GET /configs/resources/audio/normalised_Smbdytolv_r.wav HTTP/1.1" 304 -
# 127.0.0.1 - - [06/May/2025 01:35:37] "GET /configs/resources/audio/normalised_VoisonaUI.wav HTTP/1.1" 304 -
# 127.0.0.1 - - [06/May/2025 01:35:37] "GET /configs/resources/audio/normalised_1_cover2.wav HTTP/1.1" 304 -
# 127.0.0.1 - - [06/May/2025 01:35:37] "GET /configs/resources/audio/normalised_TianHou_justin.wav HTTP/1.1" 304 -
# 127.0.0.1 - - [06/May/2025 01:35:37] "GET /configs/resources/audio/normalised_Smbdytolv_CD.wav HTTP/1.1" 304 -
# 127.0.0.1 - - [06/May/2025 01:35:37] "GET /configs/resources/audio/normalised_1_AImodel.wav HTTP/1.1" 304 -
# 127.0.0.1 - - [06/May/2025 01:35:37] "GET /configs/resources/audio/normalised_Mandarin_suno.wav HTTP/1.1" 304 -
# 127.0.0.1 - - [06/May/2025 01:35:37] "GET /configs/resources/audio/normalised_Man_suno2.wav HTTP/1.1" 304 -
# 127.0.0.1 - - [06/May/2025 01:35:37] "GET /configs/resources/audio/normalised_39_39.wav HTTP/1.1" 304 -
# 127.0.0.1 - - [06/May/2025 01:35:37] "GET /configs/resources/audio/normalised_Smbdytolv_audit.wav HTTP/1.1" 304 -
# 127.0.0.1 - - [06/May/2025 01:35:37] "GET /configs/resources/audio/normalised_1_WanK.wav HTTP/1.1" 304 -
# 127.0.0.1 - - [06/May/2025 01:35:37] "GET /configs/resources/audio/normalised_1_ref.wav HTTP/1.1" 304 -
# 127.0.0.1 - - [06/May/2025 01:35:37] "GET /configs/resources/audio/normalised_Choco.wav HTTP/1.1" 304 -
# 127.0.0.1 - - [06/May/2025 01:35:37] "GET /configs/resources/audio/normalised_Suno_CantoRap.wav HTTP/1.1" 304 -
# 127.0.0.1 - - [06/May/2025 01:35:37] "GET /configs/resources/audio/normalised_Eyes_SUNO.wav HTTP/1.1" 304 -
# 127.0.0.1 - - [06/May/2025 01:35:37] "GET /configs/resources/audio/normalised_39_VT.wav HTTP/1.1" 304 -
# 127.0.0.1 - - [06/May/2025 01:35:37] "GET /configs/resources/audio/normalised_39_ref.wav HTTP/1.1" 304 -
# 127.0.0.1 - - [06/May/2025 01:35:37] "GET /configs/resources/audio/normalised_TianHou_ref.wav HTTP/1.1" 304 -
# 127.0.0.1 - - [06/May/2025 01:35:37] "GET /configs/resources/audio/normalised_39_AI_ace.wav HTTP/1.1" 304 -
# 127.0.0.1 - - [06/May/2025 01:35:37] "GET /configs/resources/audio/normalised_Utawaku.wav HTTP/1.1" 304 -
# 127.0.0.1 - - [06/May/2025 01:35:37] "GET /configs/resources/audio/normalised_ManIndie3.wav HTTP/1.1" 304 -
# 127.0.0.1 - - [06/May/2025 01:35:37] "GET /configs/resources/audio/normalised_39_AI_kim.wav HTTP/1.1" 304 -
# 127.0.0.1 - - [06/May/2025 01:35:37] "GET /configs/resources/audio/normalised_ManIndie2.wav HTTP/1.1" 304 -
# 127.0.0.1 - - [06/May/2025 01:35:37] "GET /configs/resources/audio/normalised_1_cover1.wav HTTP/1.1" 304 -
# 127.0.0.1 - - [06/May/2025 01:35:37] "GET /configs/resources/audio/normalised_TianHou_boi.wav HTTP/1.1" 304 -
# 127.0.0.1 - - [06/May/2025 01:35:37] "GET /configs/resources/audio/normalised_1_cm.wav HTTP/1.1" 304 -
# 127.0.0.1 - - [06/May/2025 01:41:45] "POST /service/write.php HTTP/1.1" 200 -
# 127.0.0.1 - - [06/May/2025 01:48:14] "GET /admin/show/mushra_noloop_nowav.html HTTP/1.1" 200 -
# 127.0.0.1 - - [06/May/2025 01:50:20] "GET /admin/ HTTP/1.1" 200 -
# 127.0.0.1 - - [06/May/2025 01:50:21] "GET /favicon.ico HTTP/1.1" 304 -
# 127.0.0.1 - - [06/May/2025 01:50:24] "GET /download/mushra_noloop_nowav.csv HTTP/1.1" 200 -
#  * Detected change in 'C:\\Users\\Jabez\\anaconda3\\Lib\\asyncio\\events.py', reloading
#  * Detected change in 'C:\\Users\\Jabez\\anaconda3\\Lib\\asyncio\\selector_events.py', reloading
#  * Restarting with watchdog (windowsapi)
#  * Debugger is active!
#  * Debugger PIN: 140-190-511
#  * Detected change in 'C:\\Users\\Jabez\\pymushra\\pymushra\\casting.py', reloading
#  * Detected change in 'C:\\Users\\Jabez\\pymushra\\pymushra\\cli.py', reloading
#  * Detected change in 'C:\\Users\\Jabez\\pymushra\\pymushra\\service.py', reloading
#  * Detected change in 'C:\\Users\\Jabez\\pymushra\\pymushra\\stats.py', reloading
#  * Detected change in 'C:\\Users\\Jabez\\pymushra\\pymushra\\utils.py', reloading
#  * Detected change in 'C:\\Users\\Jabez\\pymushra\\pymushra\\wsgi.py', reloading
#  * Detected change in 'C:\\Users\\Jabez\\pymushra\\pymushra\\__init__.py', reloading
#  * Detected change in 'C:\\Users\\Jabez\\pymushra\\tests\\test_casting.py', reloading
#  * Restarting with watchdog (windowsapi)
# Traceback (most recent call last):
#   File "<frozen runpy>", line 198, in _run_module_as_main
#   File "<frozen runpy>", line 88, in _run_code
#   File "C:\Users\Jabez\anaconda3\Scripts\pymushra.exe\__main__.py", line 4, in <module>
# ModuleNotFoundError: No module named 'pymushra'
# Obtaining file:///C:/Users/Jabez/pymushra
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'done'
#   Checking if build backend supports build_editable: started
#   Checking if build backend supports build_editable: finished with status 'done'
#   Getting requirements to build editable: started
#   Getting requirements to build editable: finished with status 'done'
#   Installing backend dependencies: started
#   Installing backend dependencies: finished with status 'done'
#   Preparing editable metadata (pyproject.toml): started
#   Preparing editable metadata (pyproject.toml): finished with status 'done'
# Requirement already satisfied: click in c:\users\jabez\anaconda3\lib\site-packages (from pymushra==0.4) (8.1.7)
# Requirement already satisfied: flask>=2.2.5 in c:\users\jabez\anaconda3\lib\site-packages (from pymushra==0.4) (3.0.3)
# Requirement already satisfied: ipython in c:\users\jabez\anaconda3\lib\site-packages (from pymushra==0.4) (8.27.0)
# Requirement already satisfied: matplotlib>=2.0.0 in c:\users\jabez\anaconda3\lib\site-packages (from pymushra==0.4) (3.9.2)
# Requirement already satisfied: numpy in c:\users\jabez\anaconda3\lib\site-packages (from pymushra==0.4) (1.26.4)
# Requirement already satisfied: pandas in c:\users\jabez\anaconda3\lib\site-packages (from pymushra==0.4) (2.2.2)
# Requirement already satisfied: patsy in c:\users\jabez\anaconda3\lib\site-packages (from pymushra==0.4) (0.5.6)
# Requirement already satisfied: scipy in c:\users\jabez\anaconda3\lib\site-packages (from pymushra==0.4) (1.13.1)
# Requirement already satisfied: seaborn in c:\users\jabez\anaconda3\lib\site-packages (from pymushra==0.4) (0.13.2)
# Requirement already satisfied: statsmodels in c:\users\jabez\anaconda3\lib\site-packages (from pymushra==0.4) (0.14.2)
# Requirement already satisfied: tinydb>=3.0.0 in c:\users\jabez\anaconda3\lib\site-packages (from pymushra==0.4) (4.8.2)
# Requirement already satisfied: tinyrecord in c:\users\jabez\anaconda3\lib\site-packages (from pymushra==0.4) (0.2.0)
# Requirement already satisfied: Werkzeug>=3.0.0 in c:\users\jabez\anaconda3\lib\site-packages (from flask>=2.2.5->pymushra==0.4) (3.0.3)
# Requirement already satisfied: Jinja2>=3.1.2 in c:\users\jabez\anaconda3\lib\site-packages (from flask>=2.2.5->pymushra==0.4) (3.1.4)
# Requirement already satisfied: itsdangerous>=2.1.2 in c:\users\jabez\anaconda3\lib\site-packages (from flask>=2.2.5->pymushra==0.4) (2.2.0)
# Requirement already satisfied: blinker>=1.6.2 in c:\users\jabez\anaconda3\lib\site-packages (from flask>=2.2.5->pymushra==0.4) (1.6.2)
# Requirement already satisfied: colorama in c:\users\jabez\anaconda3\lib\site-packages (from click->pymushra==0.4) (0.4.6)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\jabez\anaconda3\lib\site-packages (from matplotlib>=2.0.0->pymushra==0.4) (1.2.0)
# Requirement already satisfied: cycler>=0.10 in c:\users\jabez\anaconda3\lib\site-packages (from matplotlib>=2.0.0->pymushra==0.4) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\jabez\anaconda3\lib\site-packages (from matplotlib>=2.0.0->pymushra==0.4) (4.51.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\jabez\anaconda3\lib\site-packages (from matplotlib>=2.0.0->pymushra==0.4) (1.4.4)
# Requirement already satisfied: packaging>=20.0 in c:\users\jabez\anaconda3\lib\site-packages (from matplotlib>=2.0.0->pymushra==0.4) (24.1)
# Requirement already satisfied: pillow>=8 in c:\users\jabez\anaconda3\lib\site-packages (from matplotlib>=2.0.0->pymushra==0.4) (10.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\jabez\anaconda3\lib\site-packages (from matplotlib>=2.0.0->pymushra==0.4) (3.1.2)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\jabez\anaconda3\lib\site-packages (from matplotlib>=2.0.0->pymushra==0.4) (2.9.0.post0)
# Requirement already satisfied: decorator in c:\users\jabez\anaconda3\lib\site-packages (from ipython->pymushra==0.4) (5.1.1)
# Requirement already satisfied: jedi>=0.16 in c:\users\jabez\anaconda3\lib\site-packages (from ipython->pymushra==0.4) (0.19.1)
# Requirement already satisfied: matplotlib-inline in c:\users\jabez\anaconda3\lib\site-packages (from ipython->pymushra==0.4) (0.1.6)
# Requirement already satisfied: prompt-toolkit<3.1.0,>=3.0.41 in c:\users\jabez\anaconda3\lib\site-packages (from ipython->pymushra==0.4) (3.0.43)
# Requirement already satisfied: pygments>=2.4.0 in c:\users\jabez\anaconda3\lib\site-packages (from ipython->pymushra==0.4) (2.15.1)
# Requirement already satisfied: stack-data in c:\users\jabez\anaconda3\lib\site-packages (from ipython->pymushra==0.4) (0.2.0)
# Requirement already satisfied: traitlets>=5.13.0 in c:\users\jabez\anaconda3\lib\site-packages (from ipython->pymushra==0.4) (5.14.3)
# Requirement already satisfied: pytz>=2020.1 in c:\users\jabez\anaconda3\lib\site-packages (from pandas->pymushra==0.4) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\jabez\anaconda3\lib\site-packages (from pandas->pymushra==0.4) (2023.3)
# Requirement already satisfied: six in c:\users\jabez\anaconda3\lib\site-packages (from patsy->pymushra==0.4) (1.16.0)
# Requirement already satisfied: parso<0.9.0,>=0.8.3 in c:\users\jabez\anaconda3\lib\site-packages (from jedi>=0.16->ipython->pymushra==0.4) (0.8.3)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\jabez\anaconda3\lib\site-packages (from Jinja2>=3.1.2->flask>=2.2.5->pymushra==0.4) (2.1.3)
# Requirement already satisfied: wcwidth in c:\users\jabez\anaconda3\lib\site-packages (from prompt-toolkit<3.1.0,>=3.0.41->ipython->pymushra==0.4) (0.2.5)
# Requirement already satisfied: executing in c:\users\jabez\anaconda3\lib\site-packages (from stack-data->ipython->pymushra==0.4) (0.8.3)
# Requirement already satisfied: asttokens in c:\users\jabez\anaconda3\lib\site-packages (from stack-data->ipython->pymushra==0.4) (2.0.5)
# Requirement already satisfied: pure-eval in c:\users\jabez\anaconda3\lib\site-packages (from stack-data->ipython->pymushra==0.4) (0.2.2)
# Building wheels for collected packages: pymushra
#   Building editable for pymushra (pyproject.toml): started
#   Building editable for pymushra (pyproject.toml): finished with status 'done'
#   Created wheel for pymushra: filename=pymushra-0.4-py3-none-any.whl size=2710 sha256=2a49a6008b6e23f5b80fce5cd739e5bb75273d269f19d37eae3267ad2d8894e1
#   Stored in directory: C:\Users\Jabez\AppData\Local\Temp\pip-ephem-wheel-cache-t3hwp938\wheels\57\b8\df\d0bd876b105da9fb848a17e24702c718404157cd766dc3608f
# Successfully built pymushra
# Installing collected packages: pymushra
#   Attempting uninstall: pymushra
#     Found existing installation: pymushra 0.4
#     Uninstalling pymushra-0.4:
#       Successfully uninstalled pymushra-0.4
# Successfully installed pymushra-0.4
# WARNING: Ignoring invalid distribution ~%mushra (C:\Users\Jabez\anaconda3\Lib\site-packages)
# WARNING: Ignoring invalid distribution ~ (C:\Users\Jabez\anaconda3\Lib\site-packages)
# WARNING: Ignoring invalid distribution ~-mushra (C:\Users\Jabez\anaconda3\Lib\site-packages)
# WARNING: Ignoring invalid distribution ~0mushra (C:\Users\Jabez\anaconda3\Lib\site-packages)
# WARNING: Ignoring invalid distribution ~1mushra (C:\Users\Jabez\anaconda3\Lib\site-packages)
# WARNING: Ignoring invalid distribution ~2mushra (C:\Users\Jabez\anaconda3\Lib\site-packages)
# WARNING: Ignoring invalid distribution ~3mushra (C:\Users\Jabez\anaconda3\Lib\site-packages)
# WARNING: Ignoring invalid distribution ~4mushra (C:\Users\Jabez\anaconda3\Lib\site-packages)
# WARNING: Ignoring invalid distribution ~5mushra (C:\Users\Jabez\anaconda3\Lib\site-packages)
# WARNING: Ignoring invalid distribution ~6mushra (C:\Users\Jabez\anaconda3\Lib\site-packages)
# WARNING: Ignoring invalid distribution ~7mushra (C:\Users\Jabez\anaconda3\Lib\site-packages)
# WARNING: Ignoring invalid distribution ~8mushra (C:\Users\Jabez\anaconda3\Lib\site-packages)
# WARNING: Ignoring invalid distribution ~9mushra (C:\Users\Jabez\anaconda3\Lib\site-packages)
# WARNING: Ignoring invalid distribution ~=mushra (C:\Users\Jabez\anaconda3\Lib\site-packages)
# WARNING: Ignoring invalid distribution ~ymushra (C:\Users\Jabez\anaconda3\Lib\site-packages)
# WARNING: Ignoring invalid distribution ~~mushra (C:\Users\Jabez\anaconda3\Lib\site-packages)
# WARNING: Ignoring invalid distribution ~%mushra (C:\Users\Jabez\anaconda3\Lib\site-packages)
# WARNING: Ignoring invalid distribution ~ (C:\Users\Jabez\anaconda3\Lib\site-packages)
# WARNING: Ignoring invalid distribution ~-mushra (C:\Users\Jabez\anaconda3\Lib\site-packages)
# WARNING: Ignoring invalid distribution ~0mushra (C:\Users\Jabez\anaconda3\Lib\site-packages)
# WARNING: Ignoring invalid distribution ~1mushra (C:\Users\Jabez\anaconda3\Lib\site-packages)
# WARNING: Ignoring invalid distribution ~2mushra (C:\Users\Jabez\anaconda3\Lib\site-packages)
# WARNING: Ignoring invalid distribution ~3mushra (C:\Users\Jabez\anaconda3\Lib\site-packages)
# WARNING: Ignoring invalid distribution ~4mushra (C:\Users\Jabez\anaconda3\Lib\site-packages)
# WARNING: Ignoring invalid distribution ~5mushra (C:\Users\Jabez\anaconda3\Lib\site-packages)
# WARNING: Ignoring invalid distribution ~6mushra (C:\Users\Jabez\anaconda3\Lib\site-packages)
# WARNING: Ignoring invalid distribution ~7mushra (C:\Users\Jabez\anaconda3\Lib\site-packages)
# WARNING: Ignoring invalid distribution ~8mushra (C:\Users\Jabez\anaconda3\Lib\site-packages)
# WARNING: Ignoring invalid distribution ~9mushra (C:\Users\Jabez\anaconda3\Lib\site-packages)
# WARNING: Ignoring invalid distribution ~=mushra (C:\Users\Jabez\anaconda3\Lib\site-packages)
# WARNING: Ignoring invalid distribution ~ymushra (C:\Users\Jabez\anaconda3\Lib\site-packages)
# WARNING: Ignoring invalid distribution ~~mushra (C:\Users\Jabez\anaconda3\Lib\site-packages)
# WARNING: Ignoring invalid distribution ~%mushra (C:\Users\Jabez\anaconda3\Lib\site-packages)
# WARNING: Ignoring invalid distribution ~ (C:\Users\Jabez\anaconda3\Lib\site-packages)
# WARNING: Ignoring invalid distribution ~-mushra (C:\Users\Jabez\anaconda3\Lib\site-packages)
# WARNING: Ignoring invalid distribution ~0mushra (C:\Users\Jabez\anaconda3\Lib\site-packages)
# WARNING: Ignoring invalid distribution ~1mushra (C:\Users\Jabez\anaconda3\Lib\site-packages)
# WARNING: Ignoring invalid distribution ~2mushra (C:\Users\Jabez\anaconda3\Lib\site-packages)
# WARNING: Ignoring invalid distribution ~3mushra (C:\Users\Jabez\anaconda3\Lib\site-packages)
# WARNING: Ignoring invalid distribution ~4mushra (C:\Users\Jabez\anaconda3\Lib\site-packages)
# WARNING: Ignoring invalid distribution ~5mushra (C:\Users\Jabez\anaconda3\Lib\site-packages)
# WARNING: Ignoring invalid distribution ~6mushra (C:\Users\Jabez\anaconda3\Lib\site-packages)
# WARNING: Ignoring invalid distribution ~7mushra (C:\Users\Jabez\anaconda3\Lib\site-packages)
# WARNING: Ignoring invalid distribution ~8mushra (C:\Users\Jabez\anaconda3\Lib\site-packages)
# WARNING: Ignoring invalid distribution ~9mushra (C:\Users\Jabez\anaconda3\Lib\site-packages)
# WARNING: Ignoring invalid distribution ~=mushra (C:\Users\Jabez\anaconda3\Lib\site-packages)
# WARNING: Ignoring invalid distribution ~ymushra (C:\Users\Jabez\anaconda3\Lib\site-packages)
# WARNING: Ignoring invalid distribution ~~mushra (C:\Users\Jabez\anaconda3\Lib\site-packages)

# %%
# Install PyNgrok
# !pip install pyngrok
# Out:
# Requirement already satisfied: pyngrok in c:\users\jabez\anaconda3\lib\site-packages (7.2.3)
# Requirement already satisfied: PyYAML>=5.1 in c:\users\jabez\anaconda3\lib\site-packages (from pyngrok) (6.0.1)
# WARNING: Ignoring invalid distribution ~%mushra (C:\Users\Jabez\anaconda3\Lib\site-packages)
# WARNING: Ignoring invalid distribution ~ (C:\Users\Jabez\anaconda3\Lib\site-packages)
# WARNING: Ignoring invalid distribution ~-mushra (C:\Users\Jabez\anaconda3\Lib\site-packages)
# WARNING: Ignoring invalid distribution ~0mushra (C:\Users\Jabez\anaconda3\Lib\site-packages)
# WARNING: Ignoring invalid distribution ~1mushra (C:\Users\Jabez\anaconda3\Lib\site-packages)
# WARNING: Ignoring invalid distribution ~2mushra (C:\Users\Jabez\anaconda3\Lib\site-packages)
# WARNING: Ignoring invalid distribution ~3mushra (C:\Users\Jabez\anaconda3\Lib\site-packages)
# WARNING: Ignoring invalid distribution ~4mushra (C:\Users\Jabez\anaconda3\Lib\site-packages)
# WARNING: Ignoring invalid distribution ~5mushra (C:\Users\Jabez\anaconda3\Lib\site-packages)
# WARNING: Ignoring invalid distribution ~6mushra (C:\Users\Jabez\anaconda3\Lib\site-packages)
# WARNING: Ignoring invalid distribution ~7mushra (C:\Users\Jabez\anaconda3\Lib\site-packages)
# WARNING: Ignoring invalid distribution ~8mushra (C:\Users\Jabez\anaconda3\Lib\site-packages)
# WARNING: Ignoring invalid distribution ~9mushra (C:\Users\Jabez\anaconda3\Lib\site-packages)
# WARNING: Ignoring invalid distribution ~=mushra (C:\Users\Jabez\anaconda3\Lib\site-packages)
# WARNING: Ignoring invalid distribution ~ymushra (C:\Users\Jabez\anaconda3\Lib\site-packages)
# WARNING: Ignoring invalid distribution ~~mushra (C:\Users\Jabez\anaconda3\Lib\site-packages)
# WARNING: Ignoring invalid distribution ~%mushra (C:\Users\Jabez\anaconda3\Lib\site-packages)
# WARNING: Ignoring invalid distribution ~ (C:\Users\Jabez\anaconda3\Lib\site-packages)
# WARNING: Ignoring invalid distribution ~-mushra (C:\Users\Jabez\anaconda3\Lib\site-packages)
# WARNING: Ignoring invalid distribution ~0mushra (C:\Users\Jabez\anaconda3\Lib\site-packages)
# WARNING: Ignoring invalid distribution ~1mushra (C:\Users\Jabez\anaconda3\Lib\site-packages)
# WARNING: Ignoring invalid distribution ~2mushra (C:\Users\Jabez\anaconda3\Lib\site-packages)
# WARNING: Ignoring invalid distribution ~3mushra (C:\Users\Jabez\anaconda3\Lib\site-packages)
# WARNING: Ignoring invalid distribution ~4mushra (C:\Users\Jabez\anaconda3\Lib\site-packages)
# WARNING: Ignoring invalid distribution ~5mushra (C:\Users\Jabez\anaconda3\Lib\site-packages)
# WARNING: Ignoring invalid distribution ~6mushra (C:\Users\Jabez\anaconda3\Lib\site-packages)
# WARNING: Ignoring invalid distribution ~7mushra (C:\Users\Jabez\anaconda3\Lib\site-packages)
# WARNING: Ignoring invalid distribution ~8mushra (C:\Users\Jabez\anaconda3\Lib\site-packages)
# WARNING: Ignoring invalid distribution ~9mushra (C:\Users\Jabez\anaconda3\Lib\site-packages)
# WARNING: Ignoring invalid distribution ~=mushra (C:\Users\Jabez\anaconda3\Lib\site-packages)
# WARNING: Ignoring invalid distribution ~ymushra (C:\Users\Jabez\anaconda3\Lib\site-packages)
# WARNING: Ignoring invalid distribution ~~mushra (C:\Users\Jabez\anaconda3\Lib\site-packages)
# WARNING: Ignoring invalid distribution ~%mushra (C:\Users\Jabez\anaconda3\Lib\site-packages)
# WARNING: Ignoring invalid distribution ~ (C:\Users\Jabez\anaconda3\Lib\site-packages)
# WARNING: Ignoring invalid distribution ~-mushra (C:\Users\Jabez\anaconda3\Lib\site-packages)
# WARNING: Ignoring invalid distribution ~0mushra (C:\Users\Jabez\anaconda3\Lib\site-packages)
# WARNING: Ignoring invalid distribution ~1mushra (C:\Users\Jabez\anaconda3\Lib\site-packages)
# WARNING: Ignoring invalid distribution ~2mushra (C:\Users\Jabez\anaconda3\Lib\site-packages)
# WARNING: Ignoring invalid distribution ~3mushra (C:\Users\Jabez\anaconda3\Lib\site-packages)
# WARNING: Ignoring invalid distribution ~4mushra (C:\Users\Jabez\anaconda3\Lib\site-packages)
# WARNING: Ignoring invalid distribution ~5mushra (C:\Users\Jabez\anaconda3\Lib\site-packages)
# WARNING: Ignoring invalid distribution ~6mushra (C:\Users\Jabez\anaconda3\Lib\site-packages)
# WARNING: Ignoring invalid distribution ~7mushra (C:\Users\Jabez\anaconda3\Lib\site-packages)
# WARNING: Ignoring invalid distribution ~8mushra (C:\Users\Jabez\anaconda3\Lib\site-packages)
# WARNING: Ignoring invalid distribution ~9mushra (C:\Users\Jabez\anaconda3\Lib\site-packages)
# WARNING: Ignoring invalid distribution ~=mushra (C:\Users\Jabez\anaconda3\Lib\site-packages)
# WARNING: Ignoring invalid distribution ~ymushra (C:\Users\Jabez\anaconda3\Lib\site-packages)
# WARNING: Ignoring invalid distribution ~~mushra (C:\Users\Jabez\anaconda3\Lib\site-packages)

# %%
# Configure Ngrok and Setup Tunneling
from pyngrok import ngrok
ngrok.set_auth_token("2uSPKqzk9cKZs79lyhLQ0veCZr9_57664UdaQ6FTYv5Qn5nH2")
# Open a tunnel using your reserved domain
public_url = ngrok.connect(
    addr=5000,
    domain="monkfish-cheerful-mildly.ngrok-free.app"
)
#public_url = ngrok.connect(5000)
#public_url.public_url += "/admin"

# %%
# Print Public URL and start webMUSHRA application
print(public_url)
# !pymushra server
# Out:
# NgrokTunnel: "https://monkfish-cheerful-mildly.ngrok-free.app" -> "http://localhost:5000"
# t=2025-05-06T05:05:30+0100 lvl=eror msg="session closed, starting reconnect loop" obj=tunnels.session obj=csess id=2b45e5d76935 err="read EOF from remote peer"
# t=2025-05-06T05:05:30+0100 lvl=eror msg="heartbeat timeout, terminating session" obj=tunnels.session obj=csess id=000e83a340fb clientid=b307d51c6c5401641a39fede7d7b1e14

# %%
# Kill ngrok tunnel when it's done.
ngrok.kill()

# %% [markdown]
# ## Configuring a webMUSHRA Listening Test

# %%
# @title
# %%html
<iframe width="560" height="315" src="https://www.youtube.com/embed/T7sRhb6iw3Y?si=Scjx-R3G36W1oqtt" title="YouTube video player" frameborder="0" allow="accelerometer; autoplay; clipboard-write; encrypted-media; gyroscope; picture-in-picture; web-share" referrerpolicy="strict-origin-when-cross-origin" allowfullscreen></iframe>

# %% [markdown]
# ### Get your audio files into 'webmushra/configs/resources/audio/'

# %%
# Getting some wavefiles
import torchaudio
yesno_data = torchaudio.datasets.YESNO('.', download=True)

# %%
# Move some audio files to the appropriate folder
import pathlib
import shutil
files_list = list(pathlib.Path('/content/waves_yesno/').glob('*.wav'))
for file in files_list[:4]:
  shutil.copy(file, pathlib.Path('/content/webmushra/configs/resources/audio/') / file.name)

# %% [markdown]
# ## Create your Test Configuration File

# %% [markdown]
# ## Read results as Pandas DataFrame

# %%
# @title
# %%html
<iframe width="560" height="315" src="https://www.youtube.com/embed/9_ZBWYOTG9o?si=tYCFwp_lRW4mz43c" title="YouTube video player" frameborder="0" allow="accelerometer; autoplay; clipboard-write; encrypted-media; gyroscope; picture-in-picture; web-share" referrerpolicy="strict-origin-when-cross-origin" allowfullscreen></iframe>

# %%
from pymushra.pymushra import collection_to_df

# %%
from tinydb import TinyDB
db = TinyDB("/content/db/webmushra.json")
print(db.tables())
df = collection_to_df(db.table("mushra_withloop_5"))
df.head()

# %%
# @title
# %%html
<iframe src="https://www.audiolabs-erlangen.de/resources/webMUSHRA" height="400" width="900" title="Iframe Example"></iframe>
